# %% [markdown]
# ## Intermediate Value Theorem

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 14, 200)
y1 = -x*x*x*np.cos(x)*np.sin(x) + np.cos(x)*x*x
y2 = 129*x-600

plt.figure(figsize=(20,10))
# plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')
plt.grid(True)
plt.axis([5,12,-620,1000])
plt.axvline(x=5.5)
plt.axvline(x=11.8)
plt.plot(x,y1,x,y2)
# Out:
# [<matplotlib.lines.Line2D at 0x11db3d5f8>,
#  <matplotlib.lines.Line2D at 0x11db44048>]
